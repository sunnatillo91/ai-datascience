# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnatillo91/ai-datascience/blob/main/ds_praktikum_3_modul_2_amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'melbourne-housing-snapshot:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F2709%2F38454%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240406%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240406T100712Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading melbourne-housing-snapshot, 461423 bytes compressed
# [==================================================] 461423 bytes downloaded
# Downloaded and uncompressed: melbourne-housing-snapshot
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/melbourne-housing-snapshot/melb_data.csv

# %% [markdown]
# ## Avvalgi amaliyotda `GitHub`ga yuklangan `melb_data.csv` faylni `df` ga chaqirib oling

# %%
#Javobingizni shu yerga yozing
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/melb_data.csv?raw=true", index_col=0)
df.head()
# Out:
#                      Address  Rooms Type      Price Method SellerG       Date  \
# Suburb
# Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  3/12/2016
# Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin  4/02/2016
# Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin  4/03/2017
# Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin  4/03/2017
# Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson  4/06/2016
#
#             Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# Suburb
# Abbotsford       2.5    3067.0       2.0       1.0  1.0     202.0
# Abbotsford       2.5    3067.0       2.0       1.0  0.0     156.0
# Abbotsford       2.5    3067.0       3.0       2.0  0.0     134.0
# Abbotsford       2.5    3067.0       3.0       2.0  1.0      94.0
# Abbotsford       2.5    3067.0       3.0       1.0  2.0     120.0
#
#             BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# Suburb
# Abbotsford           NaN        NaN       Yarra   -37.7996    144.9984
# Abbotsford          79.0     1900.0       Yarra   -37.8079    144.9934
# Abbotsford         150.0     1900.0       Yarra   -37.8093    144.9944
# Abbotsford           NaN        NaN       Yarra   -37.7969    144.9969
# Abbotsford         142.0     2014.0       Yarra   -37.8072    144.9941
#
#                        Regionname  Propertycount
# Suburb
# Abbotsford  Northern Metropolitan         4019.0
# Abbotsford  Northern Metropolitan         4019.0
# Abbotsford  Northern Metropolitan         4019.0
# Abbotsford  Northern Metropolitan         4019.0
# Abbotsford  Northern Metropolitan         4019.0

# %%
# Mening javobim
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/melb_data.csv?raw=true")
df.head()

# %% [markdown]
# Yuqoridagi Dataframe Melburn shahri uchun sotuvdagi uylar haqida m'lumotlarni jamlagan.
#
# Quyida jadvalning ba'zi sutunlari tarjimasi berilgan (qolganini o'zingiz Google yordamida tarjima qilishingiz mumkin):
# - `Room` - xonalar soni
# - `Type` - uyning turi (h - villa/kottej/hovli; u - kvartira; t - shahardagi hovli)
# - `Price` - narx
# - `Bathroom` - tualet-vanna
# - `Landsize` - yerning maydoni (hovli uchun)
# - `BuildingArea` - Bino qurilgan yerning maydoni
# - `YearBuilt` - qurilgan yili
# - `Lattitude` va `Longitude` - GPS kordinatalar
# - `Regionname` - Region

# %% [markdown]
# # 🔺 DIQQAT!
# #### **Agar alohida aytilmagan bo'lsa, `df`ga kiritilgan o'zgartirishlarni saqlamang (`inplace=False`)**

# %% [markdown]
# ## 1-VAZIFA. `df` dagi barcha ustunlardagi`NaN` qiymatlar sonini chiqaring

# %%
#Javobingizni shu yerga yozing
df.isnull().value_counts().sum()
# Out:
# 13518

# %% [markdown]
# ## 2-VAZIFA. `df` barcha `NaN` qiymatlarni 0 bilan almashtiring

# %%
#Javobingizni shu yerga yozing
df.fillna(0)
# Out:
#                         Address  Rooms Type      Price Method   SellerG  \
# Suburb
# Abbotsford         85 Turner St      2    h  1480000.0      S    Biggin
# Abbotsford      25 Bloomburg St      2    h  1035000.0      S    Biggin
# Abbotsford         5 Charles St      3    h  1465000.0     SP    Biggin
# Abbotsford     40 Federation La      3    h   850000.0     PI    Biggin
# Abbotsford          55a Park St      4    h  1600000.0     VB    Nelson
# ...                         ...    ...  ...        ...    ...       ...
# Wheelers Hill      12 Strada Cr      4    h  1245000.0      S     Barry
# Williamstown      77 Merrett Dr      3    h  1031000.0     SP  Williams
# Williamstown        83 Power St      3    h  1170000.0      S     Raine
# Williamstown       96 Verdon St      4    h  2500000.0     PI   Sweeney
# Yarraville           6 Agnes St      4    h  1285000.0     SP   Village
#
#                      Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# Suburb
# Abbotsford      3/12/2016       2.5    3067.0       2.0       1.0  1.0
# Abbotsford      4/02/2016       2.5    3067.0       2.0       1.0  0.0
# Abbotsford      4/03/2017       2.5    3067.0       3.0       2.0  0.0
# Abbotsford      4/03/2017       2.5    3067.0       3.0       2.0  1.0
# Abbotsford      4/06/2016       2.5    3067.0       3.0       1.0  2.0
# ...                   ...       ...       ...       ...       ...  ...
# Wheelers Hill  26/08/2017      16.7    3150.0       4.0       2.0  2.0
# Williamstown   26/08/2017       6.8    3016.0       3.0       2.0  2.0
# Williamstown   26/08/2017       6.8    3016.0       3.0       2.0  4.0
# Williamstown   26/08/2017       6.8    3016.0       4.0       1.0  5.0
# Yarraville     26/08/2017       6.3    3013.0       4.0       1.0  1.0
#
#                Landsize  BuildingArea  YearBuilt CouncilArea  Lattitude  \
# Suburb
# Abbotsford        202.0           0.0        0.0       Yarra  -37.79960
# Abbotsford        156.0          79.0     1900.0       Yarra  -37.80790
# Abbotsford        134.0         150.0     1900.0       Yarra  -37.80930
# Abbotsford         94.0           0.0        0.0       Yarra  -37.79690
# Abbotsford        120.0         142.0     2014.0       Yarra  -37.80720
# ...                 ...           ...        ...         ...        ...
# Wheelers Hill     652.0           0.0     1981.0           0  -37.90562
# Williamstown      333.0         133.0     1995.0           0  -37.85927
# Williamstown      436.0           0.0     1997.0           0  -37.85274
# Williamstown      866.0         157.0     1920.0           0  -37.85908
# Yarraville        362.0         112.0     1920.0           0  -37.81188
#
#                Longtitude                  Regionname  Propertycount
# Suburb
# Abbotsford      144.99840       Northern Metropolitan         4019.0
# Abbotsford      144.99340       Northern Metropolitan         4019.0
# Abbotsford      144.99440       Northern Metropolitan         4019.0
# Abbotsford      144.99690       Northern Metropolitan         4019.0
# Abbotsford      144.99410       Northern Metropolitan         4019.0
# ...                   ...                         ...            ...
# Wheelers Hill   145.16761  South-Eastern Metropolitan         7392.0
# Williamstown    144.87904        Western Metropolitan         6380.0
# Williamstown    144.88738        Western Metropolitan         6380.0
# Williamstown    144.89299        Western Metropolitan         6380.0
# Yarraville      144.88449        Western Metropolitan         6543.0
#
# [13518 rows x 20 columns]

# %% [markdown]
# ## 3-VAZIFA. Quyidagi 2 ustun uchun o'rta qiymatlarni hisoblang:
# - BuildingArea
# - YearBuilt (**butun son qaytishi kerak**)

# %%
#Javobingizni shu yerga yozing
df_b = df.BuildingArea.mean()
df_y = df.YearBuilt.mean()
print(f"BuildingArea o'rtacha qiymati {df_b} \nYearBuilt o'rtacha qiymati {int(df_y)}")
# Out:
# BuildingArea o'rtacha qiymati 152.12890349246587
# YearBuilt o'rtacha qiymati 1964

# %% [markdown]
# **To'g'ri javob:**

# %%
print(df['BuildingArea'].mean())
print(int(df['YearBuilt'].mean()))

# %% [markdown]
# ## 4-VAZIFA: `BuildingArea` va `YearBuilt` ustunlaridagi `NaN` qiymatlarni shu ustun uchun o'rta qiymatlar bilan almashtiring
# **DIQQAT!** `YearBuilt` ustuni qiymatlari butun son bo'lishi kerak

# %%
#Javobingizni shu yerga yozing
df['BuildingArea'].fillna(df.BuildingArea.mean())
df['YearBuilt'].fillna(int(df.YearBuilt.mean()))
# Out:
# Suburb
# Abbotsford       1964.0
# Abbotsford       1900.0
# Abbotsford       1900.0
# Abbotsford       1964.0
# Abbotsford       2014.0
#                   ...
# Wheelers Hill    1981.0
# Williamstown     1995.0
# Williamstown     1997.0
# Williamstown     1920.0
# Yarraville       1920.0
# Name: YearBuilt, Length: 13518, dtype: float64

# %% [markdown]
# **To'g'ri javob:**

# %%
df.fillna({'BuildingArea':df['BuildingArea'].mean(), 'YearBuilt':int(df['YearBuilt'].mean())})

# %% [markdown]
# ## 5-VAZIFA. `.groupby()`
# Ustun uchun o'rta qiymat har doim ham aniq bo'lavermaydi. Keling avval `YearBuilt` ustuni uchun aniqroq qiymat topishga harakat qilamiz.
#
# Buning uchun `Regionname` ustuni qiymatlaridan foydalanishimiz mumkin, ya'ni bir Regiondagi binolar tahminan bir hil yillarda qurilgan deb tahmin qilsak bo'ladi.
#
# ### 5.1 `.groupby()` yordamida `df` qiymatlarini `Regionname` ustuni bo'yicha guruhlang va `YaerBuilt` ustuni uchun o'rta qiymatni hisoblang.

# %%
#Javobingizni shu yerga yozing
df.groupby('Regionname').YearBuilt.mean().astype(int)
# Out:
# Regionname
# Eastern Metropolitan          1971
# Eastern Victoria              1984
# Northern Metropolitan         1962
# Northern Victoria             1986
# South-Eastern Metropolitan    1976
# Southern Metropolitan         1960
# Western Metropolitan          1968
# Western Victoria              1982
# Name: YearBuilt, dtype: int64

# %% [markdown]
# **To'g'ri javob:**

# %%
df.groupby(['Regionname']).YearBuilt.mean().astype(int)

# %% [markdown]
# ### 5.2. `df` `YearBuilt` ustunidagi `NaN` qiymatlarni yuqoridagi qiymatlar bilan almashtiring.
# `df[df.Regionname='Eastern Metropolitan']=...`
#
# Har bir `Regionname` uchun qiymatlarni bittalab kiritmaslik uchun for siklidan foydalanishingiz mumkin.

# %%
#Javobingizni shu yerga yozing
groups = df.groupby(['Regionname']).YearBuilt.mean()
for idx in groups.index:
  df[df.Regionname==idx] = df[df.Regionname==idx].fillna({'YearBuilt':groups[idx]})

df['Regionname'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **To'g'ri javob**

# %%
groups = df.groupby(['Regionname']).YearBuilt.mean() # Bu Series obyekti
for idx in groups.index:
   df[df.Regionname==idx] = df[df.Regionname==idx].fillna({'YearBuilt':groups[idx]})

# %% [markdown]
# ### `YearBuilt` uchun yana ham aniqroq o'rta qiymat hisoblashning qanday yo'lini taklif qilgan bo'lar edingiz?

# %% [markdown]
# ## 6-VAZIFA. `BuildingArea` ustunidagi `NaN` qiymatlarni to'ldiramiz
# `BuildingArea` bino qurilgan yerning maydonini bildiradi. Bu qiymatlarni tahmin qilish uchun qaysi ustun qiymatlaridan foydalanish to'g'ri deb hisoblaysiz?

# %%
df.head()
df.groupby(['Price','Rooms']).BuildingArea.mean()
# Out:
# Price      Rooms
# 85000.0    1          NaN
# 131000.0   4        155.0
# 145000.0   1          NaN
#            4        164.0
# 160000.0   1          NaN
#                     ...
# 6400000.0  5        308.0
# 6500000.0  6        365.0
# 7650000.0  4        284.0
# 8000000.0  5        464.3
# 9000000.0  3        117.0
# Name: BuildingArea, Length: 4117, dtype: float64

# %% [markdown]
# ### 6.1 `df`ni xonalar soni bo'yicha o'rta qiymat olib ko'ring

# %%
#Javobingizni shu yerga yozing
df.groupby(['Rooms']).BuildingArea.mean()
# Out:
# Rooms
# 1      52.539597
# 2      92.831872
# 3     139.222721
# 4     208.986943
# 5     405.607347
# 6     278.513889
# 7     340.423333
# 8     256.000000
# 10           NaN
# Name: BuildingArea, dtype: float64

# %% [markdown]
# ### 6.2 Xonalar va uy turi bo'yicha o'rta qiymatni olib ko'ring.

# %%
#Javobingizni shu yerga yozing
df.groupby(['Rooms', 'Type']).BuildingArea.mean()
# Out:
# Rooms  Type
# 1      h        85.400000
#        t        70.714286
#        u        50.088250
# 2      h       103.332575
#        t       120.254150
#        u        80.852963
# 3      h       141.523648
#        t       137.620152
#        u       117.998941
# 4      h       210.398450
#        t       195.073711
#        u       161.400000
# 5      h       408.820282
#        t       159.666667
# 6      h       281.585714
#        u       171.000000
# 7      h       340.423333
# 8      h       256.000000
#        u              NaN
# Name: BuildingArea, dtype: float64

# %% [markdown]
# ### 6.3 Ahamiyat bering, 10 xonalik uylar uchun o'rta qiymat chiqmayapti. Bu nimadan dalolat beradi? Jami 10 xonalik uylar nechta? Ular bilan qanday yo'l tutishni maslahat berasiz?

# %%
#Javobingizni shu yerga yozing
df[df['Rooms'] == 10]
df.drop(df[df.Rooms==10].index, inplace=True)
# Out:
# Empty DataFrame
# Columns: [Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []

# %% [markdown]
# ### 6.4 `BuildingArea` ustunidagi mavjud `NaN` qiymatlarni o'zingiz to'g'ri deb bilgan usul bilan to'ldiring.

# %%
df['BuildingArea'] = df['BuildingArea'].fillna(df.groupby(['Rooms', 'Type'])['BuildingArea'].transform('mean'))
df.head()
# Out:
#                      Address  Rooms Type      Price Method SellerG       Date  \
# Suburb
# Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  3/12/2016
# Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin  4/02/2016
# Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin  4/03/2017
# Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin  4/03/2017
# Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson  4/06/2016
#
#             Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# Suburb
# Abbotsford       2.5    3067.0       2.0       1.0  1.0     202.0
# Abbotsford       2.5    3067.0       2.0       1.0  0.0     156.0
# Abbotsford       2.5    3067.0       3.0       2.0  0.0     134.0
# Abbotsford       2.5    3067.0       3.0       2.0  1.0      94.0
# Abbotsford       2.5    3067.0       3.0       1.0  2.0     120.0
#
#             BuildingArea    YearBuilt CouncilArea  Lattitude  Longtitude  \
# Suburb
# Abbotsford    103.332575  1962.965386       Yarra   -37.7996    144.9984
# Abbotsford     79.000000  1900.000000       Yarra   -37.8079    144.9934
# Abbotsford    150.000000  1900.000000       Yarra   -37.8093    144.9944
# Abbotsford    141.523648  1962.965386       Yarra   -37.7969    144.9969
# Abbotsford    142.000000  2014.000000       Yarra   -37.8072    144.9941
#
#                        Regionname  Propertycount
# Suburb
# Abbotsford  Northern Metropolitan         4019.0
# Abbotsford  Northern Metropolitan         4019.0
# Abbotsford  Northern Metropolitan         4019.0
# Abbotsford  Northern Metropolitan         4019.0
# Abbotsford  Northern Metropolitan         4019.0

# %% [markdown]
# ### 7-VAZIFA. Yuqoridagi vazifalardan so'ng, bizda faqatgina `CouncilArea` ustunida `NaN` qiymatlar qolishi kerak xolos.
# **Bu ustundagi `NaN` qiymatlarni avvalgi qatordagi qiymatlar bilan to'ldirib keting. Natijani saqlab qoling**

# %%
df.fillna(method='ffill', inplace=True)
df.sample(7)
# Out:
#                             Address  Rooms Type      Price Method  \
# Suburb
# West Footscray         120 Cross St      4    h   850000.0     SA
# Kensington        2/65 Bayswater Rd      2    u   420000.0     VB
# Bentleigh East         75 Orange St      3    h  1140000.0      S
# Hampton              310 Hampton St      4    h  2600000.0      S
# Frankston       4/93 Dandenong Rd E      2    u   266000.0      S
# Brighton           1/17 Tennyson St      2    u   700000.0     PI
# Richmond               28/8 Hull St      2    u   450000.0     PI
#
#                       SellerG        Date  Distance  Postcode  Bedroom2  \
# Suburb
# West Footscray            Ray  15/10/2016       8.2    3012.0       4.0
# Kensington         Alexkarbon   4/06/2016       4.2    3031.0       2.0
# Bentleigh East  hockingstuart  18/06/2016      13.9    3165.0       4.0
# Hampton                Hodges  12/06/2016      13.7    3188.0       3.0
# Frankston              Buxton  29/07/2017      38.0    3199.0       2.0
# Brighton                   RT   8/10/2016      11.2    3186.0       2.0
# Richmond               Biggin  11/02/2017       2.6    3121.0       2.0
#
#                 Bathroom  Car  Landsize  BuildingArea    YearBuilt  \
# Suburb
# West Footscray       1.0  3.0     511.0    210.398450  1968.236292
# Kensington           1.0  1.0       0.0     55.000000  1970.000000
# Bentleigh East       1.0  3.0     701.0    141.523648  1960.887041
# Hampton              1.0  2.0    1504.0    162.000000  1900.000000
# Frankston            1.0  1.0       0.0     80.852963  1968.000000
# Brighton             1.0  1.0       0.0     80.852963  1952.000000
# Richmond             1.0  1.0       0.0     66.000000  2000.000000
#
#                 CouncilArea  Lattitude  Longtitude  \
# Suburb
# West Footscray  Maribyrnong  -37.80010   144.87700
# Kensington        Melbourne  -37.79400   144.92300
# Bentleigh East    Glen Eira  -37.91780   145.08150
# Hampton             Bayside  -37.94400   145.00150
# Frankston         Frankston  -38.13275   145.13099
# Brighton            Bayside  -37.92250   144.98910
# Richmond              Yarra  -37.81730   144.99650
#
#                                 Regionname  Propertycount
# Suburb
# West Footscray        Western Metropolitan         5058.0
# Kensington           Northern Metropolitan         5263.0
# Bentleigh East       Southern Metropolitan        10969.0
# Hampton              Southern Metropolitan         5454.0
# Frankston       South-Eastern Metropolitan        17055.0
# Brighton             Southern Metropolitan        10579.0
# Richmond             Northern Metropolitan        14949.0

# %% [markdown]
# ## YAKUNIY JADVAL
# Ahamiyat bering, yakuniy jadvalda `NaN` qiymatlar bo'lmasligi kerak.

# %%
df.isnull().sum()
# Out:
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64
