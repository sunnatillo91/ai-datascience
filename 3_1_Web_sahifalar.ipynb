# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnatillo91/ai-datascience/blob/main/3_1_Web_sahifalar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
# - 3-MODUL Ma'lumotlarga ishlov berish
# - 3.1 Fayllar bilan ishlash

# %%
import pandas as pd

# %%
tashkent = pd.read_html('https://en.wikipedia.org/wiki/Tashkent')

# %%
tashkent[5].head()
# Out:
#   Climate data for Tashkent (1991–2020, extremes 1867–present)               \
#                                                          Month          Jan
# 0                                Record high °C (°F)            22.6 (72.7)
# 1                         Mean daily maximum °C (°F)             7.2 (45.0)
# 2                                 Daily mean °C (°F)             2.3 (36.1)
# 3                         Mean daily minimum °C (°F)            −1.3 (29.7)
# 4                                 Record low °C (°F)              −28 (−18)
#
#                                                                         \
#              Feb          Mar          Apr           May           Jun
# 0    27.0 (80.6)  32.5 (90.5)  36.4 (97.5)  39.9 (103.8)  43.0 (109.4)
# 1     9.5 (49.1)  16.0 (60.8)  22.3 (72.1)   28.0 (82.4)   33.6 (92.5)
# 2     4.2 (39.6)  10.2 (50.4)  15.9 (60.6)   21.1 (70.0)   26.2 (79.2)
# 3     0.1 (32.2)   5.3 (41.5)  10.1 (50.2)   14.3 (57.7)   18.4 (65.1)
# ...

# %%
len(tashkent)
# Out:
# 19

# %%
ans = pd.read_json('sample_data/anscombe.json')
ans.tail(3)
# Out:
#    Series  X     Y
# 41     IV  8  5.56
# 42     IV  8  7.91
# 43     IV  8  6.89

# %% [markdown]
# # API dan o'qish

# %%
import requests

# %%
r = requests.get('https://openlibrary.org/subjects/python.json?published_in=2010-2024')

# %%
r.status_code
# Out:
# 200

# %%
r.json().keys()
# Out:
# dict_keys(['key', 'name', 'subject_type', 'work_count', 'works'])

# %%
r.json()['work_count']
# Out:
# 110

# %%
rdf = pd.DataFrame(r.json()['works'])

# %%
rdf.head(3)
# Out:
#                   key            title  edition_count   cover_id  \
# 0   /works/OL2784125W  Learning Python             20  1312568.0
# 1   /works/OL2784127W           Python             13   988215.0
# 2  /works/OL16976951W     Think Python             11  7363360.0
#
#   cover_edition_key                                            subject  \
# 0        OL9497269M  [Python (Langage de programmation), Python (li...
# 1        OL8942751M  [Python (Computer program language), Python (L...
# 2       OL25763659M  [Computer programming, Software architecture, ...
#
#                                        ia_collection  lendinglibrary  \
# 0  [americana, inlibrary, internetarchivebooks, p...           False
# 1  [americana, binghamton-ol, inlibrary, internet...           False
# 2  [additional_collections, folkscanomy, folkscan...           False
#
#    printdisabled lending_edition        lending_identifier  \
# 0           True     OL37873566M  einfuhrunginpyth0000lutz
# ...

# %% [markdown]
# # Valyutalar Kursi

# %%
kurs_usd = requests.get('https://v6.exchangerate-api.com/v6/50505c914c9e839696e4ce78/latest/USD')
kurs_usd
# Out:
# <Response [200]>

# %%
# kurs_usd.json()

# %%
# Where USD is the base currency you want to use
url = 'https://v6.exchangerate-api.com/v6/50505c914c9e839696e4ce78/latest/USD'

# Pair of USD & UZS exchange
url_pair = 'https://v6.exchangerate-api.com/v6/50505c914c9e839696e4ce78/pair/USD/UZS'

# Making our request
# response = requests.get(url)

response = requests.get(url_pair)

data = response.json()

# Your JSON object
print(data)
data
# Out:
# {'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1711497601, 'time_last_update_utc': 'Wed, 27 Mar 2024 00:00:01 +0000', 'time_next_update_unix': 1711584001, 'time_next_update_utc': 'Thu, 28 Mar 2024 00:00:01 +0000', 'base_code': 'USD', 'target_code': 'UZS', 'conversion_rate': 12718.5517}
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1711497601,
#  'time_last_update_utc': 'Wed, 27 Mar 2024 00:00:01 +0000',
#  'time_next_update_unix': 1711584001,
#  'time_next_update_utc': 'Thu, 28 Mar 2024 00:00:01 +0000',
#  'base_code': 'USD',
#  'target_code': 'UZS',
#  'conversion_rate': 12718.5517}

# %% [markdown]
# # Qur'on API

# %%
# https://github.com/fawazahmed0/quran-api/tree/1

# quran = requests.get('https://cdn.jsdelivr.net/gh/fawazahmed0/quran-api@1/editions/uzb-muhammadsodikmu.min.json') # To'liq Qur'oni karim tafsiri

quran = requests.get('https://cdn.jsdelivr.net/gh/fawazahmed0/quran-api@1/editions/uzb-muhammadsodikmu/2/255.json') # Baqara surasi 255-oyat tafsiri

# quran = requests.get('https://cdn.jsdelivr.net/gh/fawazahmed0/quran-api@1/editions/uzb-muhammadsodikmu/1.json') # Fotiha surasi tafsiri
quran.json()
# Out:
# {'chapter': 2,
#  'verse': 255,
#  'text': 'Аллоҳ Ундан ўзга илоҳ йўқ зотдир. У тирик ва қаййумдир. Уни мудроқ ҳам, уйқу ҳам олмас. Осмонлару ердаги нарсалар Уникидир. Унинг ҳузурида Ўзининг изнисиз ҳеч ким шафоат қила олмас. У уларнинг олдиларидаги нарсани ҳам, ортларидаги нарсани ҳам билур. Унинг илмидан ҳеч нарсани иҳота қила олмаслар, магар Ўзи хоҳлаганини, халос. Унинг курсиси осмонлару ерни қамраган. Уларни муҳофаза қилиш Уни чарчатмас. Ва У Олий ва Азим зотдир. (Имом Муслим ва Имом Аҳмад Убай ибн Каъб розийаллоҳу анҳудан ривоят қилган ҳадисда, Аллоҳдаги китобидаги энг улуғ оят Курси ояти эканлиги таъкидланган. Имом Насаий Абу Умомадан ривоят қилган ҳадисда Пайғамбаримиз алайҳиссалом: «Ким ҳар фарз намоздан кейин «Оятул Курсий»ни ўқиса, унинг жаннатга киришини фақат ўлим тўсиб туради, холос», деганлар. Яъни, ўлмагани учун жаннатга кирмайди, агар вафот этса, уни жаннатдан тўсадиган ҳеч нарса қолмайди, дегани)'}

# %%
import requests

url = "https://api.quran.com/api/v4/quran/recitations/:5"

payload={}
headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"audio_files":[],"meta":{"reciter_name":null,"recitation_style":null,"filters":{}}}

# %%
import requests, json
r = requests.get('http://api.nobelprize.org/v1/laureate.json')
data = r.json()
# data['laureates']
pd.DataFrame(data['laureates'],).head()
# Out:
#   id       firstname    surname        born        died  \
# 0  1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1  2      Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2  3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3  4           Henri  Becquerel  1852-12-15  1908-08-25
# 4  5          Pierre      Curie  1859-05-15  1906-04-19
#
#              bornCountry bornCountryCode                bornCity  \
# 0  Prussia (now Germany)              DE  Lennep (now Remscheid)
# 1        the Netherlands              NL                  Arnhem
# 2        the Netherlands              NL              Zonnemaire
# 3                 France              FR                   Paris
# 4                 France              FR                   Paris
#
#        diedCountry diedCountryCode   diedCity gender  \
# 0          Germany              DE     Munich   male
# 1  the Netherlands              NL        NaN   male
# 2  the Netherlands              NL  Amsterdam   male
# ...
