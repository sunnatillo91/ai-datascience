# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnatillo91/ai-datascience/blob/main/Pandas_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
# - Ma'lumotlar tahlili. Pandas kutubxonasi
# - 2.2.4 Statistika

# %%
import pandas as pd
import numpy as np

# %%
# Keyingi mashqlar uchun ma'lumotlarni Githubdan yuklab olamiz
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df.columns = ['maydoni','aholisi']
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.sum()
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
# 2020 va 2021 yilda sotilmagan mashinalar soni
df2 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/gm_sales.csv", index_col=0)
df2.head()
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317

# %%
df2.sum()
# Out:
# 2020    168712
# 2021    124734
# dtype: int64

# %%
df2.sum(axis='columns')
# Out:
# Labo      12063
# Damas     64571
# Spark     22855
# Nexia     56105
# Cobalt    81218
# Gentra    56634
# dtype: int64

# %%
df2.mean(axis=1)
# Out:
# Labo       6031.5
# Damas     32285.5
# Spark     11427.5
# Nexia     28052.5
# Cobalt    40609.0
# Gentra    28317.0
# dtype: float64

# %%
df.mean()
# Out:
# maydoni    3.399231e+04
# aholisi    1.765062e+06
# dtype: float64

# %%
df.prod()
# Out:
# maydoni    1.538590e+55
# aholisi    2.913892e+80
# dtype: float64

# %%
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.idxmin()
# Out:
# maydoni     Andijon viloyati
# aholisi    Sirdaryo viloyati
# dtype: object

# %%
df.idxmax()
# Out:
# maydoni    Qoraqalpogʻiston Respublikasi
# aholisi                Toshkent viloyati
# dtype: object

# %%
df['maydoni'].idxmax()
# Out:
# 'Qoraqalpogʻiston Respublikasi'

# %%
df['aholisi'].idxmin()
# Out:
# 'Sirdaryo viloyati'

# %%
df['aholisi'].argmax()
# Out:
# 12

# %%
df.iloc[12]
# Out:
# maydoni      15300.0
# aholisi    4450000.0
# Name: Toshkent viloyati, dtype: float64

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.shape
# Out:
# (13119, 9)

# %%
df.tail()
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 922.6+ KB

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df['year'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['price'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data = {
    'age':[10,20,30,40,50,60],
    'year':[2010,2000,1990,1980,1970,1960]
}
obj = pd.DataFrame(data)
obj
# Out:
#    age  year
# 0   10  2010
# 1   20  2000
# 2   30  1990
# 3   40  1980
# 4   50  1970
# 5   60  1960

# %%
obj['age'].corr(obj['year'])  # yosh va tug'ilgan yildagi bog'liqlik
# Out:
# -0.9999999999999998

# %%
df['price'].corr(df['mileage'])  # narx va kilometrajdagi bog'liqlik
# Out:
# -0.537214124104646

# %%
df['price'].corr(df['engineSize'])  # narx va motor hajmidagi bog'liqlik
# Out:
# 0.5161257786169436

# %%
df.corr()  # natija 1 yoki -1 ga qancha yaqin bo'lsa shunchalik bog'liqlik yaqin bo'ladi
# Out:
# <ipython-input-28-3951f9e85fad>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()  # natija 1 yoki -1 ga qancha yaqin bo'lsa shunchalik bog'liqlik yaqin bo'ladi
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
df.corrwith(df['price'])
# Out:
# <ipython-input-29-4af89057fcc9>:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corrwith(df['price'])
# year          0.520712
# price         1.000000
# mileage      -0.537214
# tax           0.268717
# mpg          -0.438445
# engineSize    0.516126
# dtype: float64

# %%
models = df['model'].unique()  # ma'lum bir kerak bo'lgan ustunda takrorlanmagan elementlar
models.sort()
models
# Out:
# array([' A Class', ' B Class', ' C Class', ' CL Class', ' CLA Class',
#        ' CLC Class', ' CLK', ' CLS Class', ' E Class', ' G Class',
#        ' GL Class', ' GLA Class', ' GLB Class', ' GLC Class',
#        ' GLE Class', ' GLS Class', ' M Class', ' R Class', ' S Class',
#        ' SL CLASS', ' SLK', ' V Class', ' X-CLASS', '180', '200', '220',
#        '230'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2005, 2017, 2016, 2011, 2018, 2012, 2019, 2020, 2014, 2015, 2006,
#        2010, 2004, 2008, 2013, 2007, 2009, 2003, 2001, 2002, 1998, 2000,
#        1997, 1999, 1970])

# %%
df['fuelType'].unique()
# Out:
# array(['Petrol', 'Hybrid', 'Diesel', 'Other'], dtype=object)

# %%
df['model'].value_counts()  # qiymatni sanash
# Out:
#  C Class      3747
#  A Class      2561
#  E Class      1953
#  GLC Class     960
#  GLA Class     847
#  B Class       591
#  CL Class      511
#  GLE Class     461
#  SL CLASS      260
#  CLS Class     237
#  V Class       207
#  S Class       197
#  GL Class      121
#  SLK            95
#  CLA Class      86
#  X-CLASS        82
#  M Class        79
#  GLS Class      74
#  GLB Class      19
#  G Class        15
#  CLK             7
#  CLC Class       3
#  R Class         2
# 180              1
# 230              1
# 220              1
# 200              1
# Name: model, dtype: int64

# %%
df['model'].unique()
# Out:
# array([' SLK', ' S Class', ' SL CLASS', ' G Class', ' GLE Class',
#        ' GLA Class', ' A Class', ' B Class', ' GLC Class', ' C Class',
#        ' E Class', ' GL Class', ' CLS Class', ' CLC Class', ' CLA Class',
#        ' V Class', ' M Class', ' CL Class', ' GLS Class', ' GLB Class',
#        ' X-CLASS', '180', ' CLK', ' R Class', '230', '220', '200'],
#       dtype=object)

# %%
models = [' SLK',' B Class']
filtr = df['model'].isin(models)
filtr
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13114    False
# 13115     True
# 13116    False
# 13117    False
# 13118    False
# Name: model, Length: 13119, dtype: bool

# %%
df2 = df[filtr]
df2
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0           SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 12      B Class  2019  23750    Automatic      278   Diesel  145  55.4
# 15      B Class  2017  15890    Automatic    24841   Diesel  150  68.9
# 18      B Class  2017  17513    Automatic    14128   Diesel  150  68.9
# 40          SLK  2014  15990    Automatic    43955   Petrol  205  43.5
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 13033   B Class  2016  14599    Automatic    28156   Diesel   20  68.9
# 13073   B Class  2019  19350    Automatic    13674   Petrol  145  45.6
# 13108       SLK  2016  17499    Automatic    30128   Diesel   30  70.6
# 13111   B Class  2019  19344    Automatic    15257   Petrol  145  45.6
# 13115   B Class  2020  24699    Automatic     2500   Diesel  145  55.4
#
#        engineSize
# 0             1.8
# 12            2.0
# 15            1.5
# 18            2.1
# ...

# %%
filtr = df['fuelType'].isin(['Disel', 'Petrol'])
df[filtr]
# Out:
#             model  year   price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005    5200    Automatic    63000   Petrol  325  32.1
# 2        SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5        SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# ...           ...   ...     ...          ...      ...      ...  ...   ...
# 13098     C Class  2019   24499    Automatic    10635   Petrol  145  44.1
# 13099     C Class  2019   23994    Automatic    12794   Petrol  145  46.3
# 13102   GLC Class  2017   35999    Automatic    18507   Petrol  150  34.0
# 13106     C Class  2019   27999    Automatic     6537   Petrol  145  44.1
# 13111     B Class  2019   19344    Automatic    15257   Petrol  145  45.6
#
#        engineSize
# 0             1.8
# 2             5.5
# 3             4.0
# ...

# %%
df[(df.year>=2018) & (df.price<20000)]  # filtrni qo'lda yozilgan varianti
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 86      A Class  2018  18220    Automatic    10361   Diesel  145  68.9
# 89      A Class  2019  18118    Automatic    15561   Diesel  145  68.9
# 90      A Class  2019  17990    Automatic    14783   Diesel  145  65.7
# 92      A Class  2018  18888    Automatic    11565   Diesel  145  67.3
# 93      A Class  2019  19840    Automatic     6781   Petrol  145  28.5
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 13000   A Class  2018  16500    Semi-Auto    14289   Petrol  150  49.6
# 13013   B Class  2018  17995    Automatic     6025   Diesel  145  68.9
# 13018   A Class  2018  17600    Automatic    15893   Petrol  145  52.3
# 13073   B Class  2019  19350    Automatic    13674   Petrol  145  45.6
# 13111   B Class  2019  19344    Automatic    15257   Petrol  145  45.6
#
#        engineSize
# 86            1.5
# 89            1.5
# 90            1.5
# 92            1.5
# ...

# %%
df[df.transmission=='Manual']
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 34        A Class  2019  23184       Manual     1173   Petrol  145  44.8
# 56        A Class  2011   3440       Manual    74000   Diesel  150  54.3
# 61        E Class  2010   6980       Manual    79000   Petrol  300  35.3
# 63        E Class  2011   5740       Manual   115000   Diesel  160  52.3
# 81            SLK  2010   7495       Manual    59147   Petrol  300  36.2
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13011     V Class  2013  20000       Manual    58518   Diesel  305  38.7
# 13014     B Class  2017  13950       Manual     5878   Diesel   20  68.9
# 13015   GLA Class  2017  17000       Manual    26000   Petrol  145  48.7
# 13024     A Class  2016  16500       Manual    16984   Diesel   30  62.8
# 13034     A Class  2017  13391       Manual    38172   Diesel  145  72.4
#
#        engineSize
# 34            1.3
# 56            2.0
# 61            1.8
# ...
