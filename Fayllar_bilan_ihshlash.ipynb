# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnatillo91/ai-datascience/blob/main/Fayllar_bilan_ihshlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
# - 3-MODUL Ma'lumotlarga ishlov berish
# - 3.1 Fayllar bilan ishlash

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
# Out:
# --2024-03-26 04:14:44--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv’
#
# merc.csv            100%[===================>] 710.98K  --.-KB/s    in 0.03s
#
# 2024-03-26 04:14:44 (23.7 MB/s) - ‘merc.csv’ saved [728047/728047]

# %%
! git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93
# Receiving objects: 100% (145/145), 9.72 MiB | 17.68 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
df = pd.read_csv('merc.csv')

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df1 = pd.read_csv('drive/MyDrive/praktikum_datasets/uybor_scrapping.csv')

# %%
df1.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#    size  level  max_levels  price        lat        lng
# 0  57.0      4           4  52000  41.371471  69.281049
# 1  52.0      4           5  56000  41.291115  69.261104
# 2  42.0      4           4  37000  41.280784  69.223683
# 3  65.0      1           4  49500  41.290163  69.196862
# 4  70.0      3           5  55000  41.300156  69.210831

# %%
df1.sort_values(by=['price','size']).head()
# Out:
#                                                location           district  \
# 5945  город Ташкент, Мирзо-Улугбекский район, Улица ...  Мирзо-Улугбекский
# 6901  город Ташкент, Яшнободский район, Городок Авиа...        Яшнободский
# 7330        город Ташкент, Мирабадский район, Фидоийлар        Мирабадский
# 2614   город Ташкент, Яшнободский район, Мухтара Ашрафи        Яшнободский
# 3041     город Ташкент, Яшнободский район, Машиносозлар        Яшнободский
#
#       rooms  size  level  max_levels  price        lat        lng
# 5945      1  18.0      6           9  10500  41.342224  69.360758
# 6901      1  18.0      1           4  10500  41.292252  69.341907
# 7330      1  18.0      1           4  10500  41.275891  69.293713
# 2614      1  14.0      1           1  10600  41.314320  69.290429
# 3041      1  18.0      2           4  11000  41.299494  69.304386

# %%
df = pd.read_csv('drive/MyDrive/praktikum_datasets/automobile_data.csv')
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df2 = pd.read_excel('drive/MyDrive/praktikum_datasets/uzbekistan.xlsx')

# %%
df2.head()
# Out:
#           Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0   Andijon viloyati             4200  1899000
# 1    Buxoro viloyati            39400  1384700
# 2  Fargʻona viloyati             6800  2597000
# 3    Jizzax viloyati            20500   910500
# 4    Xorazm viloyati             6300  1200000

# %%
df2 = pd.read_excel('drive/MyDrive/praktikum_datasets/uzbekistan.xlsx', index_col=0, names=['hudud','maydon','aholi'])
df2.head(3)
# Out:
#                    maydon    aholi
# hudud
# Andijon viloyati     4200  1899000
# Buxoro viloyati     39400  1384700
# Fargʻona viloyati    6800  2597000

# %%
df = pd.read_csv('drive/MyDrive/praktikum_datasets/automobile_data.csv', index_col='index', nrows=4)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage  price
# index
# 0                 four         NaN             21.0  13495
# 1                 four       111.0             21.0  16500
# 2                  six       154.0              NaN  16500
# 3                 four       102.0             24.0  13950

# %%
df2 = pd.read_excel('drive/MyDrive/praktikum_datasets/uzbekistan.xlsx', index_col=0, names=['hudud','maydon','aholi'])
df2.head(3)
# Out:
#                    maydon    aholi
# hudud
# Andijon viloyati     4200  1899000
# Buxoro viloyati     39400  1384700
# Fargʻona viloyati    6800  2597000

# %% [markdown]
# #Fayllarni saqlash

# %%
df2.to_csv('newuzb.csv')

# %%
df2
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df = pd.read_csv('drive/MyDrive/praktikum_datasets/automobile_data.csv', index_col='index', nrows=4)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage  price
# index
# 0                 four         111               21  13495
# 1                 four         111               21  16500
# 2                  six         154               19  16500
# 3                 four         102               24  13950

# %%
df.to_excel('drive/MyDrive/si_loyihalar/newcars.xlsx', index=False, columns=['company','body-style','price'], )

# %% [markdown]
# # HDF5 formati

# %%
hdfobj = pd.HDFStore('data.h5')

# %%
df.head(3)
hdfobj.put('cardata', df)

# %%
df2.head(3)
hdfobj.put('uzdata', df2)

# %%
hdfobj.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
hdfobj['uzdata'].head()
# Out:
#                    maydon    aholi
# hudud
# Andijon viloyati     4200  1899000
# Buxoro viloyati     39400  1384700
# Fargʻona viloyati    6800  2597000
# Jizzax viloyati     20500   910500
# Xorazm viloyati      6300  1200000

# %%
hdfobj.close()

# %%
data = pd.read_hdf('data.h5', key='uzdata')

# %%
data.head(5)
# Out:
#                    maydon    aholi
# hudud
# Andijon viloyati     4200  1899000
# Buxoro viloyati     39400  1384700
# Fargʻona viloyati    6800  2597000
# Jizzax viloyati     20500   910500
# Xorazm viloyati      6300  1200000

# %%
data.to_hdf('data.h5', key='uzdata')
