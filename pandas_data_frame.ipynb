# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnatillo91/ai-datascience/blob/main/pandas_data_frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
# - Ma'lumotlar tahlili. Pandas kutubxonasi
# - 2.2.2 DataFrame ma'lumotlar tuzilmasi

# %%
import pandas as pd

# %%
data = {
    'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    'Temp':[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]
}
df = pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.head()
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65

# %%
df.head(3)
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56

# %%
df.shape
# Out:
# (8, 3)

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'YAIM'], index=[21,20, 19,18,17,16,15,10])
df
# Out:
#      Yil  Temp  Aholi soni YAIM
# 21  2021  1.54        33.9  NaN
# 20  2020  1.48        33.5  NaN
# 19  2019  1.56        32.9  NaN
# 18  2018  1.62        32.5  NaN
# 17  2017  1.65        31.9  NaN
# 16  2016  1.66        31.4  NaN
# 15  2015  1.64        30.9  NaN
# 10  2010  1.53        28.5  NaN

# %%
aholi = df['Aholi soni']  # Ustunlarni alohida chaqirib olish
aholi
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
df.YAIM = 0

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9     0
# 20  2020  1.48        33.5     0
# 19  2019  1.56        32.9     0
# 18  2018  1.62        32.5     0
# 17  2017  1.65        31.9     0
# 16  2016  1.66        31.4     0
# 15  2015  1.64        30.9     0
# 10  2010  1.53        28.5     0

# %%
val = pd.Series([1700,1650, 1300], index=[21,20,10])  # Ma'lum bir ustunlarga qiymat berish
df.YAIM = val

# %%
df
# Out:
#      Yil  Temp  Aholi soni    YAIM
# 21  2021  1.54        33.9  1700.0
# 20  2020  1.48        33.5  1650.0
# 19  2019  1.56        32.9     NaN
# 18  2018  1.62        32.5     NaN
# 17  2017  1.65        31.9     NaN
# 16  2016  1.66        31.4     NaN
# 15  2015  1.64        30.9     NaN
# 10  2010  1.53        28.5  1300.0

# %%
df['1500+'] = df.YAIM>1500   # Yangi ustun qo'shish va uni tekshirish uchun shart kiritish

# %%
df
# Out:
#      Yil  Temp  Aholi soni    YAIM  1500+
# 21  2021  1.54        33.9  1700.0   True
# 20  2020  1.48        33.5  1650.0   True
# 19  2019  1.56        32.9     NaN  False
# 18  2018  1.62        32.5     NaN  False
# 17  2017  1.65        31.9     NaN  False
# 16  2016  1.66        31.4     NaN  False
# 15  2015  1.64        30.9     NaN  False
# 10  2010  1.53        28.5  1300.0  False

# %%
del df['1500+']  # Kerak bo'lmagan ustunni o'chirish

# %%
df
# Out:
#      Yil  Temp  Aholi soni    YAIM
# 21  2021  1.54        33.9  1700.0
# 20  2020  1.48        33.5  1650.0
# 19  2019  1.56        32.9     NaN
# 18  2018  1.62        32.5     NaN
# 17  2017  1.65        31.9     NaN
# 16  2016  1.66        31.4     NaN
# 15  2015  1.64        30.9     NaN
# 10  2010  1.53        28.5  1300.0

# %%
# DataFrame yaratishning boshqa usuli
data = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.index.name = 'Yil'   # Ustunga nom berish

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2 = pd.DataFrame(data, index=[2021, 2019, 2017])  # Kerakli indexdagi ma'lumotlarni chiqarish

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df2.T  # Ustun va index o'rnini almashtirish
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  32.9  31.9
# Kazakhstan  18.9  18.5  18.1

# %%
arr = df2.values  # DataFrame dagi ma'lumotlarni array ko'rinishidagi o'zgaruvchiga yuklab olish

# %%
arr
# Out:
# array([[33.9, 18.9],
#        [32.9, 18.5],
#        [31.9, 18.1]])

# %%
'Tajikistan' in df.columns
# Out:
# False

# %%
2020 in df.index
# Out:
# False

# %%
usernames = {"anvar":"anvarbek223", "olim":"olimtoy", "maryam":"mary334455","javohir":"javohir445"}
emails = {"anvar":"anvar@gmail.com", "olim":"olim@mail.ru", "maryam":"mary33@gmail.com","javohir":"javohir445@gmail.com"}

data = {
    'username':usernames,
    'email':emails
}
df = pd.DataFrame(data)

# %%
df
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com

# %%
data2 = {
    'username':{"olim":"olimjon21", "maryam":"maryam2020"},
    'email':{"olim":"olimjon21@mail.ru", "maryam":"maryam20@gmail.com"}
}

# %%
df2 = df.append(pd.DataFrame(data2))
# Out:
# <ipython-input-50-320d686ce405>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df.append(pd.DataFrame(data2))

# %%
df2
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21     olimjon21@mail.ru
# maryam    maryam2020    maryam20@gmail.com
