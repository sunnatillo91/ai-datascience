# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnatillo91/ai-datascience/blob/main/DS_pandas_data_frame_2_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
# - Ma'lumotlar tahlili. Pandas kutubxonasi
# - 2.2.2 DataFrame ma'lumotlar tuzilmasi

# %%
import pandas as pd

# %%
data = {
    'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    'Temp':[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]
}
df = pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.head()
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65

# %%
df.head(3)
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56

# %%
df.shape
# Out:
# (8, 3)

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'YAIM'], index=[21,20, 19,18,17,16,15,10])
df
# Out:
#      Yil  Temp  Aholi soni YAIM
# 21  2021  1.54        33.9  NaN
# 20  2020  1.48        33.5  NaN
# 19  2019  1.56        32.9  NaN
# 18  2018  1.62        32.5  NaN
# 17  2017  1.65        31.9  NaN
# 16  2016  1.66        31.4  NaN
# 15  2015  1.64        30.9  NaN
# 10  2010  1.53        28.5  NaN

# %%
aholi = df['Aholi soni']  # Ustunlarni alohida chaqirib olish
aholi
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
df.YAIM = 0

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9     0
# 20  2020  1.48        33.5     0
# 19  2019  1.56        32.9     0
# 18  2018  1.62        32.5     0
# 17  2017  1.65        31.9     0
# 16  2016  1.66        31.4     0
# 15  2015  1.64        30.9     0
# 10  2010  1.53        28.5     0

# %%
val = pd.Series([1700,1650, 1300], index=[21,20,10])  # Ma'lum bir ustunlarga qiymat berish
df.YAIM = val

# %%
df
# Out:
#      Yil  Temp  Aholi soni    YAIM
# 21  2021  1.54        33.9  1700.0
# 20  2020  1.48        33.5  1650.0
# 19  2019  1.56        32.9     NaN
# 18  2018  1.62        32.5     NaN
# 17  2017  1.65        31.9     NaN
# 16  2016  1.66        31.4     NaN
# 15  2015  1.64        30.9     NaN
# 10  2010  1.53        28.5  1300.0

# %%
val = [1600,1550,1530,1500,1470,1450,1400,1375]
df.YAIM = val

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1600
# 20  2020  1.48        33.5  1550
# 19  2019  1.56        32.9  1530
# 18  2018  1.62        32.5  1500
# 17  2017  1.65        31.9  1470
# 16  2016  1.66        31.4  1450
# 15  2015  1.64        30.9  1400
# 10  2010  1.53        28.5  1375

# %%
df.index
# Out:
# Int64Index([21, 20, 19, 18, 17, 16, 15, 10], dtype='int64')

# %%
df.columns
# Out:
# Index(['Yil', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
indeks = df.columns

# %%
'Temp' in indeks
# Out:
# True

# %%
# DataFrame yaratishning boshqa usuli
data = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
'Tajikistan' in df.columns
# Out:
# False

# %%
2018 in df.index
# Out:
# True

# %%
usernames = {'sunnat':'sunnatillo91', 'olim':'olimboy', 'halim':'halimtoy', 'javoxir':'javoxir90'}
emails = {'sunnat':'sunnatillo91@gmail.com', 'olim':'olimboy@gmail.com', 'halim':'halimtoy@gmail.com', 'javoxir':'javoxir90@gmail.com'}

data = {
    'username':usernames,
    'email':emails
}
df = pd.DataFrame(data)

# %%
df
# Out:
#              username                   email
# sunnat   sunnatillo91  sunnatillo91@gmail.com
# olim          olimboy       olimboy@gmail.com
# halim        halimtoy      halimtoy@gmail.com
# javoxir     javoxir90     javoxir90@gmail.com

# %%
df.index
# Out:
# Index(['sunnat', 'olim', 'halim', 'javoxir'], dtype='object')

# %%
arr = ['sunnat', 'olim', 'halim', 'javoxir']

# %%
arr[0]  # arrayda indekslar takrorlanmaydi
# Out:
# 'sunnat'

# %%
arr[1]
# Out:
# 'olim'

# %%
data2 = {
    'username':{'olim':'olimjon', 'salim':'salimjon', 'maryam':'maryam21'},
    'email':{'olim':'olimjon@gmail.com', 'salim':'salimjon@gmail.com', 'maryam':'maryam21@gmail.com'}
}
# df2 = df.append(pd.DataFrame(data2))
df2 = pd.concat([df, pd.DataFrame(data2)])

# %%
df2  # DataFrame da esa indexlar takrorlanishi mumkin
# Out:
#              username                   email
# sunnat   sunnatillo91  sunnatillo91@gmail.com
# olim          olimboy       olimboy@gmail.com
# halim        halimtoy      halimtoy@gmail.com
# javoxir     javoxir90     javoxir90@gmail.com
# olim          olimjon       olimjon@gmail.com
# salim        salimjon      salimjon@gmail.com
# maryam       maryam21      maryam21@gmail.com

# %%
newindex = pd.Index(['olim', 'nafisa', 'hamida'])  # yangi indexlar yaratilayapti

# %%
newindex
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
# isin() metodi
newindex.isin(df2.index)  # yangi indexlar df2 indexlari ichida bor yoki yo'qligi solishtirib tekshirib ko'rilmoqda
# Out:
# array([ True, False, False])

# %%
df2.index.difference(newindex)  # df2 va newindex ning indexlar orasidagi farqi
# Out:
# Index(['halim', 'javoxir', 'maryam', 'salim', 'sunnat'], dtype='object')

# %%
newindex.difference(df2.index)  # newindex va df2 ning indexlar orasidagi farqi
# Out:
# Index(['hamida', 'nafisa'], dtype='object')

# %%
# union metodi  2 ta jadvaldagi indexlarni jamlaydi
df2.index.union(newindex)
# Out:
# Index(['halim', 'hamida', 'javoxir', 'maryam', 'nafisa', 'olim', 'olim',
#        'salim', 'sunnat'],
#       dtype='object')

# %% [markdown]
# .is_monotonic_increasing va .is_unique

# %%
# delete() belgilangan indexni o'chirish
df2.index.delete(0)
# Out:
# Index(['olim', 'halim', 'javoxir', 'olim', 'salim', 'maryam'], dtype='object')

# %%
df2.index.is_monotonic_increasing  # indexlar birxilmi
# Out:
# False

# %%
df2.index.is_unique
# Out:
# False

# %%
newindex.is_unique  # indexlar takrorlanmaganmi
# Out:
# True

# %% [markdown]
# **.unique()**

# %%
df2.index.unique()  # takrorlanmagan indexlarni qaytaradi
# Out:
# Index(['sunnat', 'olim', 'halim', 'javoxir', 'salim', 'maryam'], dtype='object')
